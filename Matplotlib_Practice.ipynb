# %% [markdown]
# # A notebook with different matplotlib functions created with random data or different datasets.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#%matplotlib inline

# %%
plt.plot([1,2,3,4,5,6], [9,7,8,2,4,6])

# %%
fig, ax = plt.subplots(2,2)

# %%
x = np.linspace(0, 2, 100)

fig, ax = plt.subplots()  # Create a figure and an axes.
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend()  # Add a legend.

# %%
x = np.linspace(0,2,100)

plt.plot(x,x, label='NN1')
plt.plot(x,x**4, label='NN2')
plt.plot(x,x**5, label='NN3')
plt.xlabel('test')
plt.ylabel('loss')
plt.title('Output')
plt.legend()

# %%
data = [50, 100, 150, 200, 250]
plt.bar(range(len(data)), data, color='blue')
# Out:
# <BarContainer object of 5 artists>

# %%
labels = ['Test 1', 'Test 2', 'Test 3', 'Test 4', 'Test 5', 'Test 6',]

group_one_price = [30, 40, 50, 50, 30, 20]
group_two_price = [10, 20, 30, 40, 50, 20]
group_one_tax = [1,2,1,2,1,1]
group_two_tax = [3,4,3,4,3,4]

width = 0.50
fig, ax = plt.subplots()

#create our stacked bar visualization
ax.bar(labels, group_one_price, width, align = 'edge', yerr=group_one_tax, label='First Label')
ax.bar(labels, group_two_price, width, align = 'edge', yerr=group_two_tax, bottom=group_one_price, label='Second Label')

ax.set_ylabel('Value')
ax.set_title('Scores by Group')
ax.legend()
plt.show()

# %%
#same as above but with ggplot style
plt.style.use('ggplot')
labels = ['Test 1', 'Test 2', 'Test 3', 'Test 4', 'Test 5', 'Test 6',]

group_one_price = [30, 40, 50, 50, 30, 20]
group_two_price = [10, 20, 30, 40, 50, 20]
group_one_tax = [1,2,1,2,1,1]
group_two_tax = [3,4,3,4,3,4]

width = 0.60
fig, ax = plt.subplots()

#create our stacked bar visualization
ax.bar(labels, group_one_price, width, align = 'edge', yerr=group_one_tax, label='First Label')
ax.bar(labels, group_two_price, width, align = 'edge', yerr=group_two_tax, bottom=group_one_price, label='Second Label')

ax.set_ylabel('Value')
ax.set_title('Scores by Group')
plt.xticks(rotation=90)
ax.legend()
plt.show()

# %%
plt.style.use('ggplot')

data = {'Chocolate':20, "Vanilla":10, 'Coffee': 25, 'Pistachio': 15}
names = list(data.keys())
values = list(data.values())

fig, axs = plt.subplots(1,4, figsize=(5,4), sharey=True)

axs[0].bar(names,values)
axs[1].scatter(names,values)
axs[2].plot(names,values)
fig.suptitle('Plotting')
plt.xticks(rotation=90)
# Out:
# (array([0. , 0.5, 1. ]), <a list of 3 Text major ticklabel objects>)

# %%
#Same as above, but styled better for readability
plt.style.use('ggplot')

data = {'Chocolate':20, "Vanilla":10, 'Coffee': 25, 'Pistachio': 15}
names = list(data.keys())
values = list(data.values())

fig, axs = plt.subplots(1,4, figsize=(20,5), sharey=True)

axs[0].bar(names,values)
axs[1].scatter(names,values)
axs[2].plot(names,values)
axs[3].plot(names,values)
fig.suptitle('Plotting')
#plt.xticks(rotation=90)
# Out:
# Text(0.5, 0.98, 'Plotting')

# %%
plt.style.use('ggplot')

x = np.linspace(2,10 * np.pi, 20)
y = np.sin(x ** 7)

fig, ax = plt.subplots()
ax.plot(x,y)
ax.set_title('A Single Plot')
# Out:
# Text(0.5, 1.0, 'A Single Plot')

# %%
plt.style.use('dark_background')

x = np.linspace(2,10 * np.pi, 20)
y = np.sin(x ** 7)

fig, axs = plt.subplots(2)
axs[0].plot(x,y, color='white')
axs[1].plot(x,y**2)

# %%
cd #file location

# %%
df = pd.read_csv('BitcoinHeistData.csv')
plt.style.use('ggplot')

# %%
df.head(100)
# Out:
#                                address  year  ...       income                 label
# 0    111K8kZAEnJg245r2cM6y9zgJGHZtJPy6  2017  ...  100050000.0       princetonCerber
# 1   1123pJv8jzeFQaCV4w644pzQJzVWay2zcA  2016  ...  100000000.0        princetonLocky
# 2   112536im7hy6wtKbpH1qYDWtTyMRAcA2p7  2016  ...  200000000.0       princetonCerber
# 3   1126eDRw2wqSkWosjTCre8cjjQW8sSeWH7  2016  ...   71200000.0       princetonCerber
# 4   1129TSjKtx65E35GiUo4AYVeyo48twbrGX  2016  ...  200000000.0        princetonLocky
# ..                                 ...   ...  ...          ...                   ...
# 95   11Us7kVfJS2dzryGJkSaAG4MUBvyvbZHA  2016  ...  100000000.0       princetonCerber
# 96   11UUivRcVdRJWymipDPB6WzbxzWmL7a3B  2016  ...   50000000.0        princetonLocky
# 97   11WrKpCb9YgyPaV7sPPbX5EcPQf2q8d9Z  2013  ...   30000000.0  montrealCryptoLocker
# 98  1216LTtQB2hhpU431yYifMcmnAmsh6vjz2  2017  ...   80000000.0       princetonCerber
# 99  121aKu4wARyCjEMrpWb9VfSnF9DWbjjVgn  2016  ...  400000000.0        princetonLocky
#
# [100 rows x 10 columns]

# %%
ax = df['count'].plot.hist()

# %%
df_solution = df.head(100000)

# %%
df_final_solution = df_solution[['year', 'day', 'length']]

# %%
fig, ax = plt.subplots()
bitcoin_plot = df_final_solution.plot.scatter(x='year', y='day', c='length', colormap='viridis', figsize=(20,10), ax=ax )

# %%
from google.colab import files

fig, ax = plt.subplots()
bitcoin_plot = df_final_solution.plot.scatter(x='year', y='day', c='length', colormap='viridis', figsize=(20,10), ax=ax )
plt.savefig('test_matplotlib.png', bbox_inches='tight')
files.download('test_matplotlib.png')
